# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
genes = pd.read_excel('4T1_volcano.xlsx')
genes
# Out:
#             EnsemblGeneName       GeneName                   GeneType  \
# 0      ENSMUSG00000102693.1          Txnip   gene_type protein_coding
# 1      ENSMUSG00000064842.1  5430430B14Rik              gene_type TEC
# 2      ENSMUSG00000051951.5           Egr1   gene_type protein_coding
# 3      ENSMUSG00000102851.1          Fosl1   gene_type protein_coding
# 4      ENSMUSG00000103377.1        Slc7a11   gene_type protein_coding
# ...                     ...            ...                        ...
# 51133  ENSMUSG00000111038.1        Gm26724          gene_type lincRNA
# 51134  ENSMUSG00000111855.1          Krt14   gene_type protein_coding
# 51135  ENSMUSG00000102161.1          Ncoa2   gene_type protein_coding
# 51136  ENSMUSG00000103068.2           Mlf2   gene_type protein_coding
# 51137  ENSMUSG00000103806.1         Lrrc57          gene_963935604528
#
#                                                      Chr  \
# 0      chr3;chr3;chr3;chr3;chr3;chr3;chr3;chr3;chr3;c...
# 1                                                   chr8
# 2                          chr18;chr18;chr18;chr18;chr18
# 3                                chr19;chr19;chr19;chr19
# 4      chr3;chr3;chr3;chr3;chr3;chr3;chr3;chr3;chr3;c...
# ...                                                  ...
# 51133                                        chr17;chr17
# 51134  chr11;chr11;chr11;chr11;chr11;chr11;chr11;chr1...
# 51135  chr1;chr1;chr1;chr1;chr1;chr1;chr1;chr1;chr1;c...
# 51136  chr6;chr6;chr6;chr6;chr6;chr6;chr6;chr6;chr6;c...
# 51137                                  0.789796110268112
#
#                                                    Start  \
# 0      96557957;96557960;96558889;96558892;96559070;9...
# 1                                               27279441
# 2           34859823;34861207;34861370;34862465;34862465
# 3                        5447703;5450160;5454413;5454892
# 4      49892526;50364938;50369849;50370530;50377564;5...
# ...                                                  ...
# 51133                                  27201032;27201659
# 51134  100203162;100203162;100203956;100203956;100204...
# 51135  13139105;13139159;13142475;13145301;13146599;1...
# 51136  124931386;124931405;124931405;124931425;124931...
# 51137                                  0.108257572571289
#
#                                                      End  \
# 0      96558485;96558485;96558964;96558964;96559217;9...
# 1                                               27281070
# 2           34861786;34861333;34861786;34864956;34864984
# 3                        5448055;5450351;5454520;5455945
# 4      49893147;50372366;50370059;50370799;50377741;5...
# ...                                                  ...
# 51133                                  27201268;27203071
# 51134  100203409;100203409;100204020;100204020;100204...
# 51135  chr2;chr2;chr2;chr2;chr2;chr2;chr2;chr2;chr2;c...
# 51136  124931586;124931586;124931586;124931586;124931...
# 51137                                  0.731155267319817
#
#                                               GeneLength  \
# 0                                                   3123
# 1                                                   1630
# 2                                                   4484
# 3                                                   1707
# 4                                                  13922
# ...                                                  ...
# 51133                                               1650
# 51134                                               1758
# 51135  120604238;120604238;120604238;120604238;120604...
# 51136                                               4106
# 51137                                 -0.340447832319189
#
#                                              median_CTRL  \
# 0                                              12.002072
# 1                                               9.257415
# 2                                               9.644065
# 3                                              12.503205
# 4                                              12.374598
# ...                                                  ...
# 51133                                           6.037745
# 51134                                           9.445303
# 51135  120605258;120605258;120605258;120605258;120605...
# 51136                                          12.455946
# 51137                                           0.965542
#
#                                                median_PP  \
# 0                                               7.707366
# 1                                               5.329926
# 2                                               5.967687
# 3                                               9.284114
# 4                                               9.404904
# ...                                                  ...
# 51133                                           9.643904
# 51134                                          13.152928
# 51135                                               2227
# 51136  12,713186733;13186733;13190087;13190087;131900...
# 51137                                              FALSE
#
#                                     folds_median_CTRL_PP  ttest_unpaired_p  \
# 0                                              19.626155          0.006183
# 1                                              15.215701          0.035969
# 2                                              12.784977          0.003169
# 3                                               9.311996          0.002474
# 4                                               7.833704          0.003142
# ...                                                  ...               ...
# 51133                                           0.082118          0.000477
# 51134                                           0.076541          0.009407
# 51135                                           9.054659          8.312151
# 51136  13142772;13142772;13142772;13146630;13146964;1...      15642.000000
# 51137                                                NaN               NaN
#
#        fdr_CTRL_PP  folds_median_CTRL_PP_log2   -log(p)  \
# 0         0.206772                   4.294706  2.208825
# 1         0.419278                   3.927489  1.444074
# 2         0.168641                   3.676378  2.499056
# 3         0.159504                   3.219090  2.606550
# 4         0.168593                   2.969695  2.502811
# ...            ...                        ...       ...
# 51133     0.114731                  -3.606159  3.321221
# 51134     0.236162                  -3.707624  2.026543
# 51135     1.673082                   0.003825  0.178316
# 51136    11.564066                  11.689323  0.916840
# 51137          NaN                        NaN       NaN
#
#       statistically_significant  FC_PP_CTRL  log2(fold change) Regulation  \
# 0                          TRUE    0.050952          -4.294706  Decreased
# 1                          TRUE    0.065722          -3.927489  Decreased
# 2                          TRUE    0.078217          -3.676378  Decreased
# 3                          TRUE    0.107388          -3.219090  Decreased
# 4                          TRUE    0.127654          -2.969695  Decreased
# ...                         ...         ...                ...        ...
# 51133                      TRUE   12.177609           3.606159  Increased
# 51134                      TRUE   13.064902           3.707624  Increased
# 51135                  0.742508         NaN                NaN    Neutral
# 51136                  0.800034         NaN                NaN    Neutral
# 51137                       NaN         NaN                NaN        NaN
#
#        Unnamed: 18   2
# 0              NaN NaN
# 1              NaN NaN
# 2              NaN NaN
# 3              NaN NaN
# 4              NaN NaN
# ...            ...  ..
# 51133          NaN NaN
# 51134          NaN NaN
# 51135          NaN NaN
# 51136          NaN NaN
# 51137          NaN NaN
#
# [51138 rows x 20 columns]

# %%
plt.figure(figsize = (12,6))

ax = sns.scatterplot(data = genes, x = 'log2(fold change)', y = '-log(p)',
                    hue = 'Regulation', hue_order = ['Increased', 'Decreased', 'Neutral'],
                    palette = ['red', 'blue', 'lightgray'], sizes = (40, 400))



ax.axhline(1.3, zorder = 0, c = 'k', lw = 1, ls = '--')
ax.axvline(1, zorder = 0, c = 'k', lw = 1, ls = '--')
ax.axvline(-1, zorder = 0, c = 'k', lw = 1, ls = '--')



plt.legend(loc = 1, bbox_to_anchor = (1.3,1), frameon = False, prop = {'family': 'Times New Roman','weight':'light'})

for axis in ['bottom', 'left']:
    ax.spines[axis].set_linewidth(1)
    
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

ax.tick_params(width = 2)

plt.xticks(size = 10, weight = 'light')
plt.yticks(size = 10, weight = 'light')

plt.xlabel("$log_{2}$ fold change", size = 12, fontfamily='Times New Roman')
plt.ylabel("-$log_{10}$ p", size = 12, fontfamily='Times New Roman')

ax.set_title('RNA-seq PP 5.0 vs CTRL', fontsize=14, fontweight='bold', pad = 20, fontfamily='Times New Roman')

plt.savefig('volcano.png', dpi = 300, bbox_inches = 'tight', facecolor = 'white')
plt.show()
